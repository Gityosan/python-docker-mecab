# %% [markdown]
# # TwitterAPIと形態素解析でフォロワーのいいねしたツイートの傾向を分析するレシピ

# %% [markdown]
# #### 初期化

# %%
# 初期化
import time
from collections import Counter
from io import StringIO

import MeCab
import pandas as pd
import tweepy

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

import re

from IPython.display import HTML

# %% [markdown]
# ## まずは資料通り実行

# %% [markdown]
# ### OAuth認証

# %%
CONSUMER_KEY = "0RQGlWHRlYK1D2sPmgHMr72jl"
CONSUMER_SECRET = "RYCcL5XWUpWpfNmycwXXFsGaGCp3jWBscJYXT3m6T2VPlAC9cR"
ACCESS_TOKEN = "1550863859220889600-L95YqiUqxtNDvU6uW2A13fXoeJnRQH"
ACCESS_SECRET = "43UivRhHsh72RL8FO0VUwreKtx6fCOAV6h21DDFbA27Rf"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
# OAuth認証を行うためのものです。
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
# アクセストークンをセットしておきます
api = tweepy.API(auth)
# apiオブジェクトにAPIを入れておきます。

# %% [markdown]
# ### TwitterAPIから取得

# %%
search_results = api.get_follower_ids(screen_name="ynu_bbc", count=50)
# レシピは自分のフォロワーのいいねの傾向を分析しますが、今回は一時的なアカウントでフォロワーがいないため横国生協のフォロワー≒横国生or横国OB.OGのいいねの傾向を分析しようと思う。
# フォロワーのID情報を取得しています。（count=50は50件取得の意）
# レシピにはapi.followers_idsとありますがgetを挿入してください。
favorite_tweets = ""

for result in search_results:
    try:
        time.sleep(1)
        # 1秒処理を待たせるものですが、これはなんで入ってるのかわかりません。なくても動きました。
        # あった方が10秒ほど早く動くかもしれません。
        # 理由は以下の通りかもしれません。
        # 読み込みに時間がかかる処理を実行した際、読み込み完了前にアクセスすると正しく読み込めずエラーになる場合があります。読み込み完了までの時間の猶予を生むために利用できます。
        response_list = api.get_favorites(user_id=result)
        # 同じくgetを挿入
        # 先ほど取得したIDのユーザーのいいねを押したツイートを所得し、オブジェクトに入れます。
        for response in response_list:
            favorite_tweets += response._json["text"]
            # jsonとは｢JavaScript Object Notation｣で、JavaScriptのオブジェクト記法を用いたデータ交換フォーマット」です。Jsonについての詳細はリンクを張ったので各自参照。
            # 取得したツイートデータにはツイート本文以外の情報も含まれているので（Json形式）、_json['text']とすることで本文のみを取り出します。textを指定しないとエラーが起きます。
            # エラーコード（can only concatenate str (not "dict") to str）←これはよくわからなかったです。
    except Exception as e:
        print(e)

print(favorite_tweets)

# try,except構文は、例外が発生し、処理が止まるのを防ぐため例外を変数eに格納するためのコード。

# %% [markdown]
# ### ipadicでの実行

# %%
with open("ynu_bbc_text.txt", "r", encoding="UTF-8") as f:
    text = f.read()

# print(text.replace('\n', '').replace(' ', ''))
tagger = MeCab.Tagger()
buffer = StringIO(tagger.parse(text.replace("\n", "").replace(" ", "")))

df = pd.read_csv(
    buffer,
    names=["表層形", "発音", "読み", "原形", "品詞", "品詞再分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形"],
    skipfooter=1,
    sep="[\t]",
    engine="python",
)

# display(df.count())
display(df.head())
noun_df = df[df["品詞"].str.contains("名詞") & ~df["品詞"].str.contains("代名詞", na=False)]

c = Counter(noun_df["表層形"])
print(c.most_common(30))
# Out:
#   表層形    発音    読み      原形          品詞 品詞再分類1 品詞細分類2 品詞細分類3  活用型  活用形
# 0   【   NaN   NaN       【    補助記号-括弧開   None   None   None  NaN  NaN
# 1   北    キタ    キタ       北  名詞-普通名詞-一般    NaN    NaN    0,2  NaN  NaN
# 2  ガス    ガス    ガス  ガス-gas  名詞-普通名詞-一般    NaN    NaN      1  NaN  NaN
# 3  硬式  コーシキ  コウシキ      硬式  名詞-普通名詞-一般    NaN    NaN      0  NaN  NaN
# 4  野球  ヤキュー  ヤキュウ      野球  名詞-普通名詞-一般    NaN    NaN      0  NaN  NaN
# [('t', 276), ('co', 273), ('https', 245), ('1', 81), ('野球', 73), ('7', 65), ('4', 63), ('3', 62), ('2', 61), ('5', 60), ('日', 47), ('6', 44), ('0', 43), ('戦', 42), ('年', 42), ('選手', 41), ('8', 41), ('高校', 39), ('回', 37), ('大会', 37), ('日本', 37), ('大学', 36), ('人', 36), ('部', 35), ('9', 35), ('試合', 33), ('さん', 30), ('こと', 29), ('今日', 22), ('チーム', 18)]

# %% [markdown]
# ### mecab-ipadic-neologdでの実行

# %%
with open("ynu_bbc_text.txt", "r", encoding="UTF-8") as f:
    text = f.read()

# print(text.replace('\n', '').replace(' ', ''))
tagger = MeCab.Tagger(r'-d "/usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd"')
buffer = StringIO(tagger.parse(text.replace("\n", "").replace(" ", "")))

df = pd.read_csv(
    buffer,
    names=["表層形", "品詞", "品詞細分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形", "原形", "読み", "発音"],
    skipfooter=1,
    sep="[\t,,]",
    engine="python",
)

# display(df.count())
display(df.head())
noun_df = df[df["品詞"].str.contains("名詞") & ~df["品詞"].str.contains("代名詞", na=False)]

c = Counter(noun_df["表層形"])
print(c.most_common(30))
# Out:
#      表層形  品詞 品詞細分類1 品詞細分類2 品詞細分類3 活用型 活用形      原形         読み         発音
# 0      【  記号    括弧開      *      *   *   *       【          【          【
# 1    北ガス  名詞   固有名詞     一般      *   *   *     北ガス       キタガス       キタガス
# 2  硬式野球部  名詞   固有名詞     一般      *   *   *   硬式野球部  コウシキヤキュウブ  コーシキヤキューブ
# 3      ⚾  名詞     一般      *      *   *   *  ベースボール     ベースボール     ベースボール
# 4      】  記号    括弧閉      *      *   *   *       】          】          】
# [('t', 273), ('co', 273), ('https', 246), ('7', 49), ('1', 46), ('5', 44), ('の', 37), ('0', 35), ('8', 32), ('6', 30), ('ん', 30), ('こと', 29), ('4', 24), ('2', 23), ('3', 23), ('9', 23), ('試合', 22), ('選手', 22), ('今日', 22), ('さん', 21), ('よう', 20), ('高校野球', 17), ('人', 16), ('部', 16), ('応援', 15), ('私', 15), ('日', 15), ('大会', 14), ('これ', 14), ('本日', 13)]

# %% [markdown]
# ## 自分のアカウントで再実行

# %% [markdown]
# ### OAuth認証

# %%
# 環境変数の設定
CONSUMER_KEY = "0RQGlWHRlYK1D2sPmgHMr72jl"
CONSUMER_SECRET = "RYCcL5XWUpWpfNmycwXXFsGaGCp3jWBscJYXT3m6T2VPlAC9cR"
ACCESS_TOKEN = "1550863859220889600-L95YqiUqxtNDvU6uW2A13fXoeJnRQH"
ACCESS_SECRET = "43UivRhHsh72RL8FO0VUwreKtx6fCOAV6h21DDFbA27Rf"

# 自分がOAuthを使ってアクセスするAPIがどれか指定します
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)

# アクセストークンを使って、そこにアクセスする権限があることを証明します
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# 認証情報(auth)をtweepy.APIに渡して、接続済みの各種処理が可能な大元（おおもと）の変数を作成します
api = tweepy.API(auth)
# Out:
# ids [79765255, 1368550906036252676, 1339974340499046402, 1498841626705534977, 1527247041524400128]
# 401 Unauthorized
# Not authorized.

# %% [markdown]
# ### TwitterAPIを使って取得と整形・保存

# %%
# まずは元となるアカウントを指定してそのフォロワーを取得します。
# screen_nameに元にしたいtwitterのid名を入れ、countに取得したいユーザーのidの数を指定します。
target_id = "dominisikokura"
time.sleep(1)
ids = api.get_follower_ids(screen_name=target_id, count=5)
favorite_tweets = ""
for id in ids:
    try:
        # 取得時にアクセスを集中させすぎてDDos攻撃にならないようにするためにアクセスに間隔を空けます。
        time.sleep(1)
        response_list = api.get_favorites(user_id=id)
        for response in response_list:
            print(response._json["text"])
            print("----------------------")
            favorite_tweets += response._json["text"]
    except Exception as e:
        print(e)

# 取得したツイート群をファイルに書き込んで保存する処理

# 空のファイルを書き込みモードで開いて
f = open(target_id + ".txt", "w")

# 書き込んで
f.write(favorite_tweets)

# 閉じる
f.close()
# Out:
# ファンダムの課題とな＞Billboard JAPAN運営が警鐘「チャート操作目的の再生では、音楽を“聴く”とは言えない」 https://t.co/9jlO8sAbnY
# ----------------------
# 米国初！Cruise、自動運転タクシーを海外に「輸出」へ https://t.co/coaFwQA3fG @jidountenlabから
# ----------------------
# web3のブームの一番のポイントは、中央集権か、非中央集権か、という権力の話よりも、どこまで情報がオープンになるか、オープンとクローズドのどちらが進化が早いかの比較なんじゃないかと思ってきました。
# ----------------------
# 分かる。俺も2社目のJTCに転職したら攻撃的になっていってしまったな。物静かな感じでいると周りから付け込まれて仕事を押し付けられたり、ミスを自分のせいにされたりするので、自分の身を守るために攻撃的にならざるを得ないのよね。
# ----------------------
# 早朝アンパンマン映画、終了10分前で限界が来て退出。去年よりは見ていられたので成長。
#
# シアターに我が家含めて2組。
# ONE PIECEでお忙しいだろうに上映してくれた映画館に感謝。
# ----------------------
# 採用面接でどう遠慮せずに切り込むか、についてまとめてみました。https://t.co/Mj4iINFjvG
# ----------------------
# 電力会社も動き始めていますね　東京電力EP、法人顧客のカーボンニュートラル実現を支えるカーボンニュートラルソリューションサービスを本格開始　https://t.co/QWCz4KhVlz #脱炭素　#再エネ　#電力自由化 https://t.co/wj8y0dHINU
# ----------------------
# 東京ラブストーリーのカンチはクソ男でリカは最高にいい女だという事が発覚した。
# ----------------------
# 8/26,27,28にマネーフォワードさんと金融教育のイベント＆ワークショップを開催します。ぜひご応募ください。（自分はこれから27日の資料づくりをがんばります）
# https://t.co/kai4XCq4Yy
# ----------------------
# ご存じ星野リゾート星野さんと代表池田の対談記事です。 学び多い、そして自分のことのように嬉しい
# https://t.co/1ddTXLwrH1
# ----------------------
# キース・ジャレット聴きながら昼寝。良き
# ----------------------
# 耕地放棄地の活用、地元雇用の創出、持続可能な調達、地方創生などへコーヒーでアプローチ！
# ----------------------
# 申込開始してました
# 初参加です⭐︎
# 個人サポーター！！！！
# #jawsug #jawsdays #jawsdays2022 https://t.co/dCAxLNjQJk
# ----------------------
# 地方自治体と事業をやっていると、その都道府県の未来が見えてくる。「国家」という単位ではなく「地域」という単位での変革が進む日本。
# ----------------------
# 同意です。
#
# 本当の実力者が参画している時点で、性善説が成り立つレベルの組織であるはず。よって、非合理的な仕組みが最適解となってしまった背景が必ずあります。
#
# それを把握せず表層を弄るのは、むしろ組織としての競争力を破壊しかねない。 https://t.co/R71JwbLqcj
# ----------------------
# ゆめみってユニークだなあ。微生物はともかく、シーモンキーくらいならほんとにくれそう。 https://t.co/NHGzuIi4lG
# ----------------------
# 遊佐町の皆さんは大丈夫かな... https://t.co/0OL6vOU1RZ
# ----------------------
# 中国茶が趣味（たまにお教室に通ったりしている）なのだが、今月の定期便5種のセレクトが「湿暑を流す冷茶コレクション」なのでおすすめ🍃在宅でも美味しいお茶ごくごく飲めてカフェ気分だし、毎月何がくるか楽しみなのも良い。湯を足せば1日中飲… https://t.co/W5kOGpXjR3
# ----------------------
# 三菱UFJのネットバンキング、個人は使いやすい？のに法人のUIがハチャメチャなのなんとかしてほしい。
# ----------------------
# 今までやってきた事と全く違う分野で事業作ろうとしてるんだけど、ちょっと知識量が足りないので数ヶ月は大量のインプットとその業界の人へのアプローチに費やす。40歳になっても新しい事へのチャレンジは楽しい。頑張るぞ
# ----------------------
# 401 Unauthorized
# Not authorized.
# @nodachan9 🙋🙋🙋🙇🙇🙇👍👍👍✨✨✨
# ----------------------
# 【Gallery更新】
# https://t.co/Uf2Nr58ZJI
# 今週はSNSなどで楽しむことができるARフィルターやギャル文化を体験できるようなシーンをピックアップしました！
# ぜひ体験してみてください！ https://t.co/VCAe47Xys2
# ----------------------
# 色々ぶつかって立ち止まってメソメソしてましたが、久しぶりに描けたのでAR化してみました。
# ポンコツなりに、またコツコツやっていきます。
#
# 【VRart/AR】No.98_come out【OpenBrush】… https://t.co/tvQ8qXeXd2
# ----------------------
# 激カワじゃない？？？？？？？？？？ https://t.co/KWCATEDiQ3
# ----------------------
# いつも言ってる事をnodachanにも伝えたら、ハマってくれたみたいwww https://t.co/zExTchHMQa
# ----------------------
# Chujoさんと「【メタバース業界】カスタマーサクセス業務内容なんでも話します！」について話しませんか？ https://t.co/D5kPE3kqJj #Meety #STYLY #VR #AR #メタバース #カスタマーサクセス
# ----------------------
# うわぁあ🫣 https://t.co/80j77CgMkM
# ----------------------
# AIに九龍城建ててもらうの楽しすぎる。
# #midjourney https://t.co/Dkxe0jrjJt
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 馬刺しの大葉も凄くいい感じに表現できたけど、このスプーンが1番驚き
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/Upo3qqNztY
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# このお店に決めたのが外に置いてたメニューに馬刺しがあったから！
# 久しぶりの馬刺し
# 美味しかったー
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/5eL03stRXa
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# VRと言えば唐揚げ
# アツすぎたのか器が溶けた🤔
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/3G3aktbtLC
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 大好物のからすみ
# いやー美味しいすね
# お酒飲みたくなったけど我慢しました！
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/1GZjY56GGz
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# nodachanが頼んだ茄子のお刺身
# 涼しげでとても美味しかった
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/2bL06jPItM
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# nodachanとデートしたお店の突き出し
# 嘘
# ワイクウDAYの打ち上げ第一弾でした😂
# 僕が疲れ過ぎてたのでスタッフ君とは名張で仕切り直して打ち上げします😆
#
# #スキャン飯… https://t.co/PLqb8w9cjE
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 初ウーバーで頼んだラーメン！
# 盛り付けを自分でするの楽しかった😆
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ https://t.co/4gJwcsAhiI
# ----------------------
# @nodachan9 nodachanおつかれさまっす
# ----------------------
# 今日はお手伝いをさせていただいておりました https://t.co/yiIsKAh1LK
# ----------------------
# つかめっちゃ髪伸びたわ https://t.co/MlkGKc9cGV
# ----------------------
# 中野のまんだらけと、戸田さんのねこの手書店で、古本と雑誌爆買してきた。 https://t.co/qguKpgVZi2
# ----------------------
# 今日のStyly紹介
# MAYU KUROIWA AR
# 実際に動かせて遊べて楽しいARでした！
# ＃ARToVILLA_OFFICIAL
# https://t.co/1mMu8AwUgf
# ----------------------
# 関内でバイトがてら音だけ聞いてた
# 来年こそはみたい! 試験期間に被らなければの話だけど https://t.co/XFE6cvQj5i
# ----------------------
# 教育、ビジネスに興味ある方と話してみたいです！
# ・教育学部
# ・理系
# ・23卒の代
# ・現在休学中
# ・1on1募集中
# ・GW明けからインターン
# ・将来的に教育事業をしたい！
# ・現在もいくつか教育活動をしてます！
#
# #23卒 #24卒… https://t.co/AMVbxGSGeu
# ----------------------
# きづかなかった https://t.co/C1PmtuWyGf
# ----------------------
# 明日オリエンテーリングの新歓出るか迷ってる…
# ----------------------
# 今更ですが春から横国(機械工学EP)です
# ----------------------
# 今更ですが、理工学部で情報工学EPです。
# よろしくおねがいします！
#
# #春から横国
# ----------------------
# 春から横国理工　機械工学EPです！
# よろしくお願いします！
# #春から横国
# ----------------------
# #春から横国 経済学部
# 友達が沢山欲しい
# 学部関わらずフォローしてください！
# ----------------------
# 横国理工学部電情EPの春から横国生です。履修登録も仮履修登録も分からないです。(電情の人は分かるかもしれないですが金髪で髪結んでた男です…)情弱すぎるので助けてください！ #春から横国
# ----------------------
# #春から横国 経営学部です、、、
# 友だちできんし履修もわからんし明日は大学に行くのかどうかもわかりません、助けてください🥲
# ----------------------
# 横国経済学部です。よろしくお願いします。　　＃春から横国
# ----------------------
# 春から横国理工学部の数物電子情報系学科の電子情報システムEPです。よろしくお願いします。
# #春から横国
# ----------------------
# 機械工学です。お願いします
#  #春から横国
# ----------------------
# 横国経済学部です！
# 知り合いがいないので仲良くして欲しいです。
# よろしくお願いします！
#
# #春から横国
# ----------------------
# 足先に金属板の保護があればなんでもいいそうです(アコ/回答協力: @rosic_ynu)
#
# #Peing #質問箱 https://t.co/A47bM0m1Ks
# ----------------------
# 横国物理工学の方…履修について誰か教えて欲しいです….
# ----------------------
# おはようございます🥱
# 今日は寝すぎて朝に
# 何もできませんでした...笑
#
# たくさん寝た分、
# 夜はデザイン追加と
# ポートフォリオ制作を頑張るよ
#
# 今日は金曜日。
# お酒も飲みながら作業しよう🥃
# #Web制作 #駆け出しエンジニアと繋がりたい #プログラミング
# ----------------------
# 8月のアマプラ配信映画
# 熱すぎる！！！
#
# 8/27🍿スパイダーマン：ノーウェイ・ホーム
# 8/27🍿ラストナイト・イン・ソーホー
# 8/8🍿ヴェノム：レット・ゼア・ビー・カーネイジ
# 8/8🍿 ディア・エヴァン・ハンセン https://t.co/SShtwmrirL
# ----------------------
# 誰かに頼ることを覚える
#
# 基本的に誰かに相談をせず自分で解決してきた人生なので、行き詰まった時頼る人がいないのが僕の課題だと最近気付きました
#
# いいようで悪いものなので誰かを頼るという難しいことにチャレンジしてみます
# ----------------------
# 今日来たホテルが引くくらい豪華だったｗ https://t.co/qiXV7lmSHe
# ----------------------
# 内定ないのに説明会から探す段階の同士はもういないよね😭持ち駒も全て無くなった😭
# ----------------------
# 退勤なう。この時間の駅は変な奴が多い。
# ----------------------
# PHPなりJavaなりGoなり、好きな言語を使える多様性がWeb開発の魅力なのに、フロントもサーバーサイドもJS使おう、みたいな風潮が悲しいってマックの女子高生がいってた
# #駆け出しエンジニアと繋がりたい
# #プログラミング
# ----------------------
# 転職すると自分が社会人何年目なのか分からなくなる
# ----------------------
# CCSPという資格に合格したっぽいです。はじめましてISC2。試験普通につらかった
# ----------------------
# #いいねした人全員フォローする
# ゆっくりフォローします😗
# 既にFFの人は♻️🙌
# ----------------------
# わーいほめてほめて〜！ https://t.co/vZr7ckMV4S
# ----------------------
# Twitterを始めて1ヶ月ですが
# こんなにフォロワーさんが…！
#
# 多くの方々のおかげで
# ここまで頑張ることができ
# 少しずつ案件をいただけるようになりました！
#
# みなさんいつもありがとうございます！😊
# これからもよろしくお願いしま… https://t.co/Jg0h9WPkX8
# ----------------------
# 👀✨ https://t.co/1eUzlo0Vu9
# ----------------------
# NNTだけど投票行ってくるよ🥹
# ----------------------
# 上司に退職の意向を伝えました。
# ----------------------
# 日本も平和では無いってことだなぁ。
# ----------------------
# アプリ11個作ってわかったこと
#
# アプリ制作でプログラムを書く時間は全体の1〜2割
#
# 売れるアプリ作りはプログラム力よりどんな気持ちになるかを想像する力の方が求められる気がする
# ----------------------
# 今日はこれでお仕事終わり！
# ----------------------
# 久しぶりにDJしたい、、、
# ----------------------

# %% [markdown]
# ### ipadicで実行

# %%
with open("dominisikokura.txt", "r", encoding="UTF-8") as f:
    text = f.read()
    text = text.replace("\r\n", "").replace("\n", "").replace(" ", "")

tagger = MeCab.Tagger()
buffer = StringIO(tagger.parse(text))

df = pd.read_csv(
    buffer,
    names=["表層形", "発音", "読み", "原形", "品詞", "品詞再分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形"],
    skipfooter=1,
    sep="[\t]",
    engine="python",
)

# display(df.count())
display(df.head())
noun_df = df[df["品詞"].str.contains("名詞") & ~df["品詞"].str.contains("代名詞", na=False)]

c = Counter(noun_df["表層形"])
df = pd.DataFrame(c.most_common(30), columns=["単語", "回数"])

display(HTML("<h1>Twitter フォロワー分析</h1>"))
display(df)
# Out:
#    表層形    発音    読み   原形             品詞 品詞再分類1 品詞細分類2 品詞細分類3  活用型  活用形
# 0  にゃん   ニャン   ニャン  にゃん             副詞    NaN    NaN      1  NaN  NaN
# 1    。   NaN   NaN    。        補助記号-句点   None   None   None  NaN  NaN
# 2   世界   セカイ   セカイ   世界     名詞-普通名詞-一般    NaN    NaN    1,2  NaN  NaN
# 3  不思議   フシギ   フシギ  不思議  名詞-普通名詞-形状詞可能    NaN    NaN      0  NaN  NaN
# 4   発見  ハッケン  ハッケン   発見   名詞-普通名詞-サ変可能    NaN    NaN      0  NaN  NaN
# <h1>Twitter フォロワー分析</h1>
#        単語   回数
# 0       t  272
# 1      co  270
# 2   https  245
# 3       1   72
# 4       2   69
# 5       人   66
# 6       3   56
# 7      こと   55
# 8       4   45
# 9       8   43
# 10      横   42
# 11      6   41
# 12      方   39
# 13     さん   39
# 14      国   39
# 15      7   39
# 16     大学   38
# 17      9   35
# 18      5   35
# 19     参加   34
# 20      春   34
# 21      0   33
# 22      笑   33
# 23      会   30
# 24     時間   28
# 25  エンジニア   26
# 26      回   25
# 27      日   25
# 28     自分   23
# 29      者   23

# %% [markdown]
# ### mecab-ipadic-neologdでの実行

# %%
tagger = MeCab.Tagger(r'-d "/usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd"')
buffer = StringIO(tagger.parse(text))

df = pd.read_csv(
    buffer,
    names=["表層形", "品詞", "品詞細分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形", "原形", "読み", "発音"],
    skipfooter=1,
    sep="[\t,,]",
    engine="python",
)

display(df.head())
noun_df = df[df["品詞"].str.contains("名詞") & ~df["品詞"].str.contains("代名詞", na=False)]

c = Counter(noun_df["表層形"])
df = pd.DataFrame(c.most_common(30), columns=["単語", "回数"])

display(HTML("<h1>Twitter フォロワー分析</h1>"))
display(df)
# Out:
#        表層形   品詞 品詞細分類1 品詞細分類2 品詞細分類3     活用型  活用形       原形          読み  \
# 0      にゃん   副詞     一般      *      *       *    *      にゃん         ニャン
# 1        。   記号     句点      *      *       *    *        。           。
# 2  世界不思議発見   名詞   固有名詞     一般      *       *    *  世界不思議発見  セカイフシギハッケン
# 3        、   記号     読点      *      *       *    *        、           、
# 4       いい  形容詞     自立      *      *  形容詞・イイ  基本形       いい          イイ
#
#            発音
# 0         ニャン
# 1           。
# 2  セカイフシギハッケン
# 3           、
# 4          イイ
# <h1>Twitter フォロワー分析</h1>
#        単語   回数
# 0       t  270
# 1      co  270
# 2   https  266
# 3       の   64
# 4      こと   55
# 5       人   48
# 6      横国   42
# 7       8   37
# 8       方   35
# 9       春   35
# 10     よう   33
# 11      7   32
# 12      2   31
# 13      6   31
# 14     参加   30
# 15      3   29
# 16      0   27
# 17      1   26
# 18      5   26
# 19  エンジニア   26
# 20      9   23
# 21     自分   19
# 22     大学   19
# 23     今日   18
# 24   動画編集   18
# 25     さん   17
# 26    説明会   17
# 27      ん   17
# 28      笑   17
# 29     仕事   15

# %% [markdown]
# ## 課題点の列挙

# %%
# いくつか問題点が見つかる

# 1. https://t.co/が多く含まれている
# 下記は「：」や「/」が名詞分類に混ざっていないことの確認のための出力(空出力が望ましい)
display(
    noun_df[
        noun_df["表層形"].str.contains(":", na=False)
        | noun_df["表層形"].str.contains("/", na=False)
    ]
)


# 2. https://t.co/ランダム英数字のランダム英数字の部分が直後の文字列と結合して正しく判別されていない(下記は一例)
display(noun_df[noun_df["表層形"].str.contains("iPhone")])
# Out:
# Empty DataFrame
# Columns: [表層形, 品詞, 品詞細分類1, 品詞細分類2, 品詞細分類3, 活用型, 活用形, 原形, 読み, 発音]
# Index: []
#               表層形  品詞 品詞細分類1 品詞細分類2 品詞細分類3 活用型 活用形      原形     読み     発音
# 1120  AwUgfiPhone  名詞     一般      *      *   *   *       *   None   None
# 1168       iPhone  名詞   固有名詞     一般      *   *   *  iPhone  アイフォン  アイフォン

# %% [markdown]
# ## 課題点を改善

# %%
target_id = "dominisikokura"
time.sleep(1)
ids = api.get_follower_ids(screen_name=target_id, count=50)
favorite_tweets = ""
for id in ids:
    try:
        time.sleep(1)
        response_list = api.get_favorites(user_id=id)
        for response in response_list:
            fixed_tweet = re.sub(
                r"https.*$", "", response._json["text"], flags=re.MULTILINE
            )
            favorite_tweets += fixed_tweet
            print(fixed_tweet)
            print("----------------------")
    except Exception as e:
        print(e)


f = open(target_id + ".txt", "w")
f.write(favorite_tweets)
f.close()
# Out:
# ファンダムの課題とな＞Billboard JAPAN運営が警鐘「チャート操作目的の再生では、音楽を“聴く”とは言えない」
# ----------------------
# 米国初！Cruise、自動運転タクシーを海外に「輸出」へ
# ----------------------
# web3のブームの一番のポイントは、中央集権か、非中央集権か、という権力の話よりも、どこまで情報がオープンになるか、オープンとクローズドのどちらが進化が早いかの比較なんじゃないかと思ってきました。
# ----------------------
# 分かる。俺も2社目のJTCに転職したら攻撃的になっていってしまったな。物静かな感じでいると周りから付け込まれて仕事を押し付けられたり、ミスを自分のせいにされたりするので、自分の身を守るために攻撃的にならざるを得ないのよね。
# ----------------------
# 早朝アンパンマン映画、終了10分前で限界が来て退出。去年よりは見ていられたので成長。
#
# シアターに我が家含めて2組。
# ONE PIECEでお忙しいだろうに上映してくれた映画館に感謝。
# ----------------------
# 採用面接でどう遠慮せずに切り込むか、についてまとめてみました。
# ----------------------
# 電力会社も動き始めていますね　東京電力EP、法人顧客のカーボンニュートラル実現を支えるカーボンニュートラルソリューションサービスを本格開始
# ----------------------
# 東京ラブストーリーのカンチはクソ男でリカは最高にいい女だという事が発覚した。
# ----------------------
# 8/26,27,28にマネーフォワードさんと金融教育のイベント＆ワークショップを開催します。ぜひご応募ください。（自分はこれから27日の資料づくりをがんばります）
#
# ----------------------
# ご存じ星野リゾート星野さんと代表池田の対談記事です。 学び多い、そして自分のことのように嬉しい
#
# ----------------------
# キース・ジャレット聴きながら昼寝。良き
# ----------------------
# 耕地放棄地の活用、地元雇用の創出、持続可能な調達、地方創生などへコーヒーでアプローチ！
# ----------------------
# 申込開始してました
# 初参加です⭐︎
# 個人サポーター！！！！
# #jawsug #jawsdays #jawsdays2022
# ----------------------
# 地方自治体と事業をやっていると、その都道府県の未来が見えてくる。「国家」という単位ではなく「地域」という単位での変革が進む日本。
# ----------------------
# 同意です。
#
# 本当の実力者が参画している時点で、性善説が成り立つレベルの組織であるはず。よって、非合理的な仕組みが最適解となってしまった背景が必ずあります。
#
# それを把握せず表層を弄るのは、むしろ組織としての競争力を破壊しかねない。
# ----------------------
# ゆめみってユニークだなあ。微生物はともかく、シーモンキーくらいならほんとにくれそう。
# ----------------------
# 遊佐町の皆さんは大丈夫かな...
# ----------------------
# 中国茶が趣味（たまにお教室に通ったりしている）なのだが、今月の定期便5種のセレクトが「湿暑を流す冷茶コレクション」なのでおすすめ🍃在宅でも美味しいお茶ごくごく飲めてカフェ気分だし、毎月何がくるか楽しみなのも良い。湯を足せば1日中飲…
# ----------------------
# 三菱UFJのネットバンキング、個人は使いやすい？のに法人のUIがハチャメチャなのなんとかしてほしい。
# ----------------------
# 今までやってきた事と全く違う分野で事業作ろうとしてるんだけど、ちょっと知識量が足りないので数ヶ月は大量のインプットとその業界の人へのアプローチに費やす。40歳になっても新しい事へのチャレンジは楽しい。頑張るぞ
# ----------------------
# 401 Unauthorized
# Not authorized.
# @nodachan9 🙋🙋🙋🙇🙇🙇👍👍👍✨✨✨
# ----------------------
# 【Gallery更新】
#
# 今週はSNSなどで楽しむことができるARフィルターやギャル文化を体験できるようなシーンをピックアップしました！
# ぜひ体験してみてください！
# ----------------------
# 色々ぶつかって立ち止まってメソメソしてましたが、久しぶりに描けたのでAR化してみました。
# ポンコツなりに、またコツコツやっていきます。
#
# 【VRart/AR】No.98_come out【OpenBrush】…
# ----------------------
# 激カワじゃない？？？？？？？？？？
# ----------------------
# いつも言ってる事をnodachanにも伝えたら、ハマってくれたみたいwww
# ----------------------
# Chujoさんと「【メタバース業界】カスタマーサクセス業務内容なんでも話します！」について話しませんか？
# ----------------------
# うわぁあ🫣
# ----------------------
# AIに九龍城建ててもらうの楽しすぎる。
# #midjourney
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 馬刺しの大葉も凄くいい感じに表現できたけど、このスプーンが1番驚き
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# このお店に決めたのが外に置いてたメニューに馬刺しがあったから！
# 久しぶりの馬刺し
# 美味しかったー
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# VRと言えば唐揚げ
# アツすぎたのか器が溶けた🤔
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 大好物のからすみ
# いやー美味しいすね
# お酒飲みたくなったけど我慢しました！
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# nodachanが頼んだ茄子のお刺身
# 涼しげでとても美味しかった
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# nodachanとデートしたお店の突き出し
# 嘘
# ワイクウDAYの打ち上げ第一弾でした😂
# 僕が疲れ過ぎてたのでスタッフ君とは名張で仕切り直して打ち上げします😆
#
# #スキャン飯…
# ----------------------
# Scaniverse特集
# 東京出張2022サマー編
#
# 初ウーバーで頼んだラーメン！
# 盛り付けを自分でするの楽しかった😆
#
# #スキャン飯
# #メシグラメトリ
# #Scaniverse
# #モバスキョ
# ----------------------
# @nodachan9 nodachanおつかれさまっす
# ----------------------
# 今日はお手伝いをさせていただいておりました
# ----------------------
# つかめっちゃ髪伸びたわ
# ----------------------
# 中野のまんだらけと、戸田さんのねこの手書店で、古本と雑誌爆買してきた。
# ----------------------
# 今日のStyly紹介
# MAYU KUROIWA AR
# 実際に動かせて遊べて楽しいARでした！
# ＃ARToVILLA_OFFICIAL
#
# ----------------------
# 関内でバイトがてら音だけ聞いてた
# 来年こそはみたい! 試験期間に被らなければの話だけど
# ----------------------
# 教育、ビジネスに興味ある方と話してみたいです！
# ・教育学部
# ・理系
# ・23卒の代
# ・現在休学中
# ・1on1募集中
# ・GW明けからインターン
# ・将来的に教育事業をしたい！
# ・現在もいくつか教育活動をしてます！
#
# #23卒 #24卒…
# ----------------------
# きづかなかった
# ----------------------
# 明日オリエンテーリングの新歓出るか迷ってる…
# ----------------------
# 今更ですが春から横国(機械工学EP)です
# ----------------------
# 今更ですが、理工学部で情報工学EPです。
# よろしくおねがいします！
#
# #春から横国
# ----------------------
# 春から横国理工　機械工学EPです！
# よろしくお願いします！
# #春から横国
# ----------------------
# #春から横国 経済学部
# 友達が沢山欲しい
# 学部関わらずフォローしてください！
# ----------------------
# 横国理工学部電情EPの春から横国生です。履修登録も仮履修登録も分からないです。(電情の人は分かるかもしれないですが金髪で髪結んでた男です…)情弱すぎるので助けてください！ #春から横国
# ----------------------
# #春から横国 経営学部です、、、
# 友だちできんし履修もわからんし明日は大学に行くのかどうかもわかりません、助けてください🥲
# ----------------------
# 横国経済学部です。よろしくお願いします。　　＃春から横国
# ----------------------
# 春から横国理工学部の数物電子情報系学科の電子情報システムEPです。よろしくお願いします。
# #春から横国
# ----------------------
# 機械工学です。お願いします
#  #春から横国
# ----------------------
# 横国経済学部です！
# 知り合いがいないので仲良くして欲しいです。
# よろしくお願いします！
#
# #春から横国
# ----------------------
# 足先に金属板の保護があればなんでもいいそうです(アコ/回答協力: @rosic_ynu)
#
# #Peing #質問箱
# ----------------------
# 横国物理工学の方…履修について誰か教えて欲しいです….
# ----------------------
# おはようございます🥱
# 今日は寝すぎて朝に
# 何もできませんでした...笑
#
# たくさん寝た分、
# 夜はデザイン追加と
# ポートフォリオ制作を頑張るよ
#
# 今日は金曜日。
# お酒も飲みながら作業しよう🥃
# #Web制作 #駆け出しエンジニアと繋がりたい #プログラミング
# ----------------------
# 8月のアマプラ配信映画
# 熱すぎる！！！
#
# 8/27🍿スパイダーマン：ノーウェイ・ホーム
# 8/27🍿ラストナイト・イン・ソーホー
# 8/8🍿ヴェノム：レット・ゼア・ビー・カーネイジ
# 8/8🍿 ディア・エヴァン・ハンセン
# ----------------------
# 誰かに頼ることを覚える
#
# 基本的に誰かに相談をせず自分で解決してきた人生なので、行き詰まった時頼る人がいないのが僕の課題だと最近気付きました
#
# いいようで悪いものなので誰かを頼るという難しいことにチャレンジしてみます
# ----------------------
# 今日来たホテルが引くくらい豪華だったｗ
# ----------------------
# 内定ないのに説明会から探す段階の同士はもういないよね😭持ち駒も全て無くなった😭
# ----------------------
# 退勤なう。この時間の駅は変な奴が多い。
# ----------------------
# PHPなりJavaなりGoなり、好きな言語を使える多様性がWeb開発の魅力なのに、フロントもサーバーサイドもJS使おう、みたいな風潮が悲しいってマックの女子高生がいってた
# #駆け出しエンジニアと繋がりたい
# #プログラミング
# ----------------------
# 転職すると自分が社会人何年目なのか分からなくなる
# ----------------------
# CCSPという資格に合格したっぽいです。はじめましてISC2。試験普通につらかった
# ----------------------
# #いいねした人全員フォローする
# ゆっくりフォローします😗
# 既にFFの人は♻️🙌
# ----------------------
# わーいほめてほめて〜！
# ----------------------
# Twitterを始めて1ヶ月ですが
# こんなにフォロワーさんが…！
#
# 多くの方々のおかげで
# ここまで頑張ることができ
# 少しずつ案件をいただけるようになりました！
#
# みなさんいつもありがとうございます！😊
# これからもよろしくお願いしま…
# ----------------------
# 👀✨
# ----------------------
# NNTだけど投票行ってくるよ🥹
# ----------------------
# 上司に退職の意向を伝えました。
# ----------------------
# 日本も平和では無いってことだなぁ。
# ----------------------
# アプリ11個作ってわかったこと
#
# アプリ制作でプログラムを書く時間は全体の1〜2割
#
# 売れるアプリ作りはプログラム力よりどんな気持ちになるかを想像する力の方が求められる気がする
# ----------------------
# 今日はこれでお仕事終わり！
# ----------------------
# 久しぶりにDJしたい、、、
# ----------------------
# 🍖リベルタBBQについて🍖
# 新歓の場で告知しており人数が集まってきましたので、予約状況を公開します📝
#
# 新宿の屋上テラス(ビアガーデン)を貸し切ってやります😎
#
# カレンダーや手帳に"肉"と書いておきましょう！笑笑
#
# インカレサーク…
# ----------------------
# 🍖BBQ🍖
# 夏は川沿いで肉焼きます🍹笑
#
# 水鉄砲をもってくるので、
# 濡れてもいい格好をしてきましょう🔫
# (去年はりおちゃんが狙われて帰り不機嫌で怖かった...笑)
#
# お肉と飲み物が毎回に余るので、特に一人暮らしの人はエコバッグを持…
# ----------------------
# ❣️お揃いDisney❣️
# ⇨真っ黒、ストリート系、制服、等
# お揃い案、募集中💡
#
# 新歓に一回でも参加してくれた人限定でディズニーの参加者募集します🤗
#
# 《集合》舞浜9時
# 《内容》50人規模で4班に分かれて行動！班替え2回！最後に…
# ----------------------
# 🌋遠足 FUJI-Q🌋
# 前回と同じく、3男の運転(※早稲田フル単エリートの安全運転です笑)車10台で大移動しようと思います😎
#
# 日程については最新の活動日程ツイートからご確認ください😘
#
# インカレサークルリベルタ✍️
# ----------------------
# 🎐浅草遠足🎐
#
# 都内でアクセスが良い遠足の場所といえば？･･･浅草です笑
# 暖かい時期は男女浴衣を着て散歩します👘
#
# 昼は3グループに分かれて行動し、夜は集合写真を撮りその後は自由行動になります🎈残れる人はお好み焼き屋さんで二次会し…
# ----------------------
# 〜サークル係について〜
# 大学、専門、学年関係なしで楽しいことを何でもやるサークルです👭👫👬
#
# 2年生以上も新入生として扱いますので係につく心配はないです👌笑
#
# もちろんやりたければウェルカムです！😆
# たまに幹部会もあります！笑…
# ----------------------
# 🌸2022新歓🌸
# 8/6・8/8・8/18
#
# 暇つぶしの参加も大歓迎です🤣
#
# 【新規参加予約 現在】
# 8/6 🚹34🚺36
#
#
# 応募は公式LINEまで
# LINE ID⇒…
# ----------------------
# 🗓新歓日程🗓
# 8/6・8/8・8/18
# テスト終わりで予約増えてきました😆
#
# 〜新歓内容〜
# 【集合】東新宿駅19:00
# 【時間】19:00〜21:00
# 【参加費】1000円
# ※詳細は申込みの際に連絡
#
# 〜よくある質問〜
# ・遅刻OK…
# ----------------------
# ◼️今後の活動予定◻️
# 8月☞ 新歓、BBQ、USJ、熱海
# 9月☞ 沖縄、ディズニー
# 10月☞ 富士急、浅草
# 11月☞  チームラボ
# etc...
#
# 新歓に来た方は誰でも入会できます🙆🏻‍♀️
# 活動予定は色々ありますが『行きたい行…
# ----------------------
# 〜グループLINE〜
# リベルタメンバー続々と増えてます🔥
# 当サークルに興味を持ってくれてる方が多いようで、とても嬉しく思っております🥺
#
# 荒らし防止のため新歓の場でグループLINEに招待してるので、興味ある方はサークル幹部に口頭で…
# ----------------------
# 🏝9月は沖縄旅行🏝
# コロナで高校時代の修学旅行が消滅したという声が多いので沖縄行きましょう✈️笑
#
# 過去40人規模でしたが、修学旅行の代わりなので100人まで参加を受け付けたいと思います🧐
#
# 皆が楽しい思い出を作れるよう旅行係で計…
# ----------------------
# グルメ巡り(🍔)
#
# 写真は先日お邪魔したハンバーガー屋さん"eggslut"です！
# とても美味しかったです😋
#
# オールラウンドサークルなのでグルメ巡りもします😋
#
# 💡アイデア募集中💡
# クレープ、アイス、パンケーキ、ピザ、ラーメン、…
# ----------------------
# 🍰カフェ巡り🍰
#
# 🚉中目黒、代官山、世田谷、三軒茶屋、表参道、吉祥寺、西荻窪、蔵前、水道橋
# 付近でのカフェ巡りが多いです😋
#
# 当サークルは男女スタバ店員が多いのでカフェ情報が豊富🔍
#
# インカレサークルリベルタ
# ----------------------
# 🌎USJ×大阪旅行🌎
# 前回はハロウィンの時期にいきました💀
# コスプレ×USJは気分も上がり、とにかく楽しすぎちゃいました🥺
#
# 予定表ツイートに日程載ってますか、こちらは新歓に来てくれた人を条件に、50人限定で参加を受け付けたいと思…
# ----------------------
# 🍖リベルタBBQについて🍖
# 新歓の場で告知しており人数が集まってきましたので、予約状況を公開します📝
#
# 新宿の屋上テラス(ビアガーデン)を貸し切ってやります😎
#
# カレンダーや手帳に"肉"と書いておきましょう！笑笑
#
# インカレサーク…
# ----------------------
# 🍖BBQ🍖
# 夏は川沿いで肉焼きます🍹笑
#
# 水鉄砲をもってくるので、
# 濡れてもいい格好をしてきましょう🔫
# (去年はりおちゃんが狙われて帰り不機嫌で怖かった...笑)
#
# お肉と飲み物が毎回に余るので、特に一人暮らしの人はエコバッグを持…
# ----------------------
# ❣️お揃いDisney❣️
# ⇨真っ黒、ストリート系、制服、等
# お揃い案、募集中💡
#
# 新歓に一回でも参加してくれた人限定でディズニーの参加者募集します🤗
#
# 《集合》舞浜9時
# 《内容》50人規模で4班に分かれて行動！班替え2回！最後に…
# ----------------------
# 🌋遠足 FUJI-Q🌋
# 前回と同じく、3男の運転(※早稲田フル単エリートの安全運転です笑)車10台で大移動しようと思います😎
#
# 日程については最新の活動日程ツイートからご確認ください😘
#
# インカレサークルリベルタ✍️
# ----------------------
# 🎐浅草遠足🎐
#
# 都内でアクセスが良い遠足の場所といえば？･･･浅草です笑
# 暖かい時期は男女浴衣を着て散歩します👘
#
# 昼は3グループに分かれて行動し、夜は集合写真を撮りその後は自由行動になります🎈残れる人はお好み焼き屋さんで二次会し…
# ----------------------
# 〜サークル係について〜
# 大学、専門、学年関係なしで楽しいことを何でもやるサークルです👭👫👬
#
# 2年生以上も新入生として扱いますので係につく心配はないです👌笑
#
# もちろんやりたければウェルカムです！😆
# たまに幹部会もあります！笑…
# ----------------------
# 401 Unauthorized
# Not authorized.
# #brandedlikes
# いいね押すと変化が！？
# ----------------------
# 購入品
# 七月中にはどっちも終わらせたい！
# ----------------------
# オンライン授業を図書館で受ける方へ。
# オンライン授業受講スペースは、｢声を出しても良い場所👄｣として用意しています。ご自身が喋らない授業の場合は、リフレッシュルームやパノラマ閲覧席の方がWi-Fiが強くておすすめです📶
# ----------------------
# 情報科学面白そうだけど木4ミクロと被ってて泣く
# ----------------------
# テニサーありすぎて分からない
# ----------------------
# コンリテ落ちて惰眠を貪る朝になっちまった
# ----------------------
# 新入生募集中です！
# #春から横国
# ----------------------
# 入学式でめちゃめちゃ寂しかったので大学垢を作りました横国経済新一年です 助けてください
# #春から横国 #春からynu
# ----------------------
# @NK18690158 いいですよ〜✌
# ----------------------
# @NK18690158 よろしく！
# ----------------------
# 12日の英語基礎力テストとは？？え？なになに？どういう？
#
# あ、みんな明日写真撮ろうね〜！全然声かけてね〜怖くないよ😻
# ----------------------
# 色々あって遅れましたがこの春から横浜国立大学の経済学部に進学します。
#
# わからないことばかりなので不安ですが、横浜国立大学の皆さんよろしくお願いします！
#
# #春から横国
# ----------------------
# 友達少なくてなかなか同志を見つけられない！
# 奇跡的にソフトテニスに興味ある人いませんか？😭
# ----------------------
# 新入生経済学部で
# 履修よく分かんないって人へ！
#
# 実際に自分が1年生向けに
# 組んでみたので
#
# それを参考にして
# 組む際のコツとか注意点を
# 履修の画像と共に紹介します！
#
# 参考にしたい方は
# DMを送ってくれたら対応します！
# ----------------------
# 新1年の皆さん入学おめでとうございます㊗️ ソフトテニス部ではいつでも体験入部お待ちしております！　興味がある方は連絡お願いします🤲
# ----------------------
# 仮登録は画面左のプロフィール下『利用仮登録』から行います。
# 教員が未対応でまだ仮登録が出来ない科目もあります。順次対応していきますのでお待ち下さい。
# ----------------------
# 履修の茶色の冊子と緑の冊子ダブルで無くしたオワタ＼(^o^)／
# ----------------------
# 彫刻の森美術館のガラスの塔めちゃきれかった
# ----------------------
# やはりナレッジキングのメンバーがとんでもないな。これは四皇。
#
# でも僕もかなりついていけてるぞ、、、出たかったな。 #99人の壁
# ----------------------
# Hi this is confidential
# ----------------------
# 弊社事業の就活コーチングに関わる募集が始まっています！
# 自らを高め、就活生の規範となり、引っ張っていくことに興味がある方は是非ご一読を！
#
# 自分も成長しながら、就活生の人生のターニングポイントをつくりたい方、募集 by NINJA…
# ----------------------
# これから息子とプリンセスウタのライブ見に行く！
# #ワンピース #ウタ #シャンクス
# #ONEPIECE_FILMRED #ウタカタララバイ
# ----------------------
# いまから #99人の壁 そしてそのままSTAMPEDE！今日は #ONEPIECE を堪能できる最高の日！
# ----------------------
# 最高だった、、、、シャンクスかっこよすぎる
# ----------------------
# オーラリング、無事にちゃんと注文できていたみたいで安心！！！楽しみすぎるぅ👀
# ----------------------
# 今日の和牛、とても柔らかく美味しそうだったので撮影してみました🍖
# 北海道産黒毛和牛です！
# ----------------------
# このお寿司3貫、一貫平均1000円です
# ----------------------
# 最近ワンピースを履修したこともあり、メチャクチャおもろかった
#
# 【ワンピースアラバスタ以降クイズ】21巻までしか知らない粗品に正解されたら即アウト【霜降り明星】
# ----------------------
# 起きたらなぜか佐渡島にいた。
# ----------------------
# いよいよ！！！！ずっと楽しみにしてた！
#
# #ONEPIECEFILMRED
# ----------------------
# すきぴがｳｪﾌﾞｽﾘｰについて言及するようになってしまった、、、、一体どうすれば、、、、
# ----------------------
# ここのホットサンドめっちゃ美味いねん
# ----------------------
# いつもんとこ
# ----------------------
# @sotaronishida 今、そのTOHOシネマズららぽーと横浜にいます、、14時の回で見れそうにありません、残念🫤
# ----------------------
# こないだちょっと聞かれたので虚空に叫んどくね
# DMでする占いは1問500円
# 対面なら美味しいご飯奢ってくれれば占います！
# 以上！
# ----------------------
# フォロワー1000人超えてた
# ----------------------
# REDみてきたー！
# 激面白かったね〜〜〜〜
# #ワンピース
# #ワンピースフィルムレッド
# #シャンクスの娘
# ----------------------
# 怖かったけどベースしょってたから、最悪ベースで殴って逃げればいいと思ったら言えた
# ----------------------
# 自作のカードリーダーで学生証のデータを読み取るのは成功した
# ----------------------
# 休日野音キャップ部
# ----------------------
# ドーナツ食べたい
# ----------------------
# 大学入って初めて服買った
# ----------------------
# 大学初のカラオケで喉ぶっ壊れた
# ----------------------
# 色々あって、今頭の中こんな感じ
# ----------------------
# Webアプリの実装、機能サクサク追加してくの楽しすぎ～
# ----------------------
# アカウントを作成すると無料体験チケットが貰えるキャンペーン、7月31日（日）23:59 までです 🔥🔥🔥
#
# ぜひこの機会にお試しください 👋
# ----------------------
# 今日がクラスメソッド最終出社日でした
# 2年半本当に楽しかったしクラメソ入ったことが大きな転機になったなと思う
# 一緒に働いてくださったみなさまありがとうございました！
# 来週からまた新しい環境でがんばるぞい💪
# ----------------------
# 【新着記事🎉】
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート
#
# うにうにと積み上げ! #駆け出しエンジニア
# ----------------------
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート：CodeZine（コードジン）
# ----------------------
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート
# ----------------------
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート
# #ITニュース #CodeZine
#
# ----------------------
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート
#
# ----------------------
# エンジニア相談サービス「mentory」、月額プランをより柔軟に選べるようアップデート
# ----------------------
# ＼ピックアップニュース／
#
# エンジニア相談サービスmentory、月額プランをより柔軟に選べるように
#
# #エンジニア
# ----------------------
# エンジニア相談サービスmentory、月額プランをより柔軟に選べるように
# ----------------------
# エンジニア相談サービスmentory、月額プランをより柔軟に選べるように
# ----------------------
# エンジニア相談サービスmentory、月額プランをより柔軟に選べるように
# ----------------------
# エンジニア相談サービスmentory、月額プランをより柔軟に選べるように
# ----------------------
# @mentoryjp ありがとうございます！検討させていただきます✨
# ----------------------
# TechBlog書きましたー🙌
#
# ----------------------
# AWS lambdaの実行がうまくいきません助けて、、、
# ----------------------
# こんにちは🐘
# 明日、19:00からtwitter spaceにてエンジニアが人事に色々聴いてみよう企画をやってみます！
# 基本、私が人事に質問してそれを垂れ流す感じなので、ラジオを聴く感覚でご参加くださいませ〜
# 緊張する〜😇
#
# co…
# ----------------------
# Java得意な人教えて欲しい😭
# ----------------------
# 401 Unauthorized
# Not authorized.
# 昔、原理研（＝統一教会）が台頭してきたので対抗して原付理念研究会（原理研）という50cc限定のバイクサークル作って、謎の原付バイク軍団結成した。
# しまいには学内では原理研＝バイクというイメージを根付かせ、宗教の方の原理研を「紛らわ…
# ----------------------
# 【重版出来】
# 『徹底検証　日本の右傾化』（塚田穂高 編著）の重版分が出来上がりました。大変お待たせしました。
#
# 政治と宗教の関係が鋭く問われる今、必読の論考を多数収録しています。
#
# 早ければ８月３日（水）あたりから、書店さんの店頭…
# ----------------------
# 『例外社会』はアニメ・漫画の分析は措くとしても20-21世紀のグローバルな政治社会的分析が通り良すぎてこれ一冊あればいいのでは？と思ってしまう
# ----------------------
# 「「助け合う共同体」像 覆す」
# 「伝統的共同体としての素朴なムラ像に対して、松沢裕作は本書で徹底した批判を加える」
# 「近現代史の見通しを考え直させる迫力をもった仕事である」
#
# 7/31読売新聞で、苅部直さんが松沢裕作『日本近代村落…
# ----------------------
# 人の話を聞くというのは、何も人の言うことを聞けとか発言を真摯に受け止めろということではなく単に対話をしろということ。一方的に自分の知識を披露したいならそれはただのマウント取って気持ちよくなっているだけ。
# ----------------------
# すまんねぇ
# ちょっと取り込んでて読書会でれんかった
# ----------------------
# あるていど規模の大きくなった読書会に必ず出現する「自分の感想を延々としゃべり続ける人」にの呼び方を考えないといけない。
# ----------------------
# 『例外社会』も他大学の図書館から取り寄せてゲットしたので読む
# ----------------------
# 都社×の学科長が野良フットサルにハマりすぎて足腐りそうになった話、めちゃくちゃ好きすぎる
# ----------------------
# 国葬抗議デモをやります。
# 何処でどうやるか、思案中です。
# ----------------------
# 伊藤計劃の『ハーモニー』に不満だったのは、心を消すといいながら、結局ハーモニー（類的本質）が不問に付されることでした。ガイストとかいう不愉快なゴミへの信仰が無批判に残されているのは、むしろ楽観主義にみえますね
# ----------------------
# では、私と対話するのではどうでしょうか？
# ----------------------
# 世界に対してなんらの影響を及ぼす力も持たないくせに、「おれたち二人がいれば、無敵じゃね？」と無根拠に確信できるような友人を20代で持つことができたのは本当に幸いだった。今なら、鼠と別れるときの「僕」の気持ちも、山崎と別れるときの佐藤の気持ちも痛いほどよくわかる
# ----------------------
# そういえばよく誤解されるので呟いておきますが、ぼくと「都市社会××学科」の主催者さんとは全くの別人で、ぼく自身は同団体さんとは（少なくとも今のところ）一切関係ありません。
# ----------------------
# ✨✨7月29日(金)公開✨✨
#
# 陰謀論、秘密結社、悪魔崇拝、人身売買…
# すべての陰にそのドラッグの存在があった💊💊💊
#
# #アドレノクロム
# 7/29(金)全国ロードショー！
#
# 奴らは殺した人間の内臓で
# 究極のドラッグ＜アドレノクロム…
# ----------------------
# 「社会は絶対に想像以下だ」って言葉かっこよすぎ
# ----------------------
# "伝説"で"待望"の初回講義記録　～驚愕の講義内容が明らかに?!～｜横浜国立大学都市社会××学科のブログ #note
# ----------------------
# もうちょっと頑張らないと、文字のでかさで負けている。
# でも、こんなことすら認められない大学がどんどん増えてきているのが嘆かわしい。
# ----------------------
# 例の「都市社会☓☓学科」学科長の「初回講義記録」が公開された！
# 相変わらず絶好調で面白い。
# まあ、彼らの活動は今のところはこのblogと、ゲリラ的な掲示板ジャックだけのようだが、今後どんな展開を見せるかには注目したい。
# ----------------------
# @YDK28760541 ありがとう！！
# ところで、かぶに似てるって言われたことありませんか？？
# ----------------------
# おはようございます。
# 眠すぎて眠いです💤
#
# 京都で見かけた鳩が色違いだったので写真撮ってしまいました✨
#
# 二度寝して参ります。
# おやすみなさい。
# ----------------------
# 実は大根はプランターでも育てれます
# ----------------------
# 最近暑すぎて定期的に水やりをしないと大根が枯れてしまいます。みなさんも定期的に水分補給して熱中症にならないよう気をつけてください！
# ----------------------
# みんな鬼ごっこしたくないか？
# ----------------------
# 横国大根サークルがスピーカーにいるの草
# ----------------------
# YDK（横国大根サークル)、オフ会はオフ会だから大根食わないの面白すぎる
# ----------------------
# 大根サークル意外と活動活発でおもろい
# ----------------------
# お葉よう！
# ----------------------
# おは葉！
# ----------------------
# 皆さんこんにちはYDK(横国大根サークル)です！今日スペース開きます。時間は教えません、多くの人が参加してくれることを願っています、ご参加お待ちしております！
# ----------------------
# 今度YDKでスペース開こうと思っています！どんなことをしているサークルなのか、会長はどういう人なのか、気になる方はぜひぜひご参加ください！(15分間くらいで終わる予定です、日時については後ほど連絡したいと思います)
# ----------------------
# 大根サークル暴れてんなぁ
# ----------------------
# 綺麗になったね💕
# @YDK28760541
# ----------------------
# 逆にキャラが確立されたから嬉しくなってきた笑笑
# どうも女チー牛です！
# ----------------------
# 働きたくないですわ
# ----------------------
# さっき揺れました？
# ----------------------
# ねぶた〜〜〜〜
# ----------------------
# 久本雅美様をお見かけしましたわ〜
# ----------------------
# あらあら！！
# ----------------------
# 別垢で、1秒とか0秒とかいう名前のスペースが流れてきて、なんだこいつと思ってたらこの垢でした
# ----------------------
# GermanがGmarnに見える
# ----------------------
# きよ先生の夏休みが始まりました。帰省の帰路を検討中・・・。北陸新幹線まわりは大雨でサンダーバード動いてないしなぁ。
# ----------------------
# 飯テロを見るたびに、俺は死に場所を探している
# ----------------------
#
# ----------------------
# みんなからの匿名質問を募集中！
#
# こんな質問に答えてるよ
# ● 法政？立教？
# ● 一緒にラーメン食べたいですの
# ● いつもツイート面白くて好きです…
# ● つかぬことお聞き致しますが、麻…
# #質問箱 #匿名質問募集中
#
#
# ----------------------
# 金ないから出かけられなくて、結局勉強かTwitterの二択しかないのどうにかしてもろて
# ----------------------
# だる
# ----------------------
# ロッキン対応のためか，なんと蘇我駅に簡易Suica改札機が登場。朝は混んでたな。簡単に工事できるの？？
# ----------------------
# みんなからの匿名質問を募集中！
#
# こんな質問に答えてるよ
# ● 弊学にもあるの知らなかった！…
# ● カタツムリが素早い生き物だった…
# ● 三人が横一列に並び、ケミンの合…
# ● パクチーは食べられますか？
# #質問箱 #匿名質問募集中
#
#
# ----------------------
# 給料が振り込まれるのは、来月の中旬なので、夏休みの間はあんまり遊べません
# アーメン
# ----------------------
# 浅虫にて
# ----------------------
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded
# 429 Too Many Requests
# 88 - Rate limit exceeded

# %% [markdown]
# ## 課題点改善後再実行

# %%
with open("dominisikokura.txt", "r", encoding="UTF-8") as f:
    text = f.read()
    text = text.replace("\r\n", "").replace("\n", "").replace(" ", "")
tagger = MeCab.Tagger(r'-d "/usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd"')
buffer = StringIO(tagger.parse(text))

df = pd.read_csv(
    buffer,
    names=["表層形", "品詞", "品詞細分類1", "品詞細分類2", "品詞細分類3", "活用型", "活用形", "原形", "読み", "発音"],
    skipfooter=1,
    sep="[\t,,]",
    engine="python",
)

display(df.head())
noun_df = df[df["品詞"].str.contains("名詞") & ~df["品詞"].str.contains("代名詞", na=False)]

c = Counter(noun_df["表層形"])
df = pd.DataFrame(c.most_common(30), columns=["単語", "回数"])

display(HTML("<h1>Twitter フォロワー分析</h1>"))
display(df)
# Out:
#      表層形  品詞 品詞細分類1 品詞細分類2 品詞細分類3 活用型 活用形     原形     読み     発音
# 0  ファンダム  名詞   固有名詞     一般      *   *   *  ファンダム  ファンダム  ファンダム
# 1      の  助詞    連体化      *      *   *   *      の      ノ      ノ
# 2     課題  名詞     一般      *      *   *   *     課題    カダイ    カダイ
# 3      と  助詞    格助詞     引用      *   *   *      と      ト      ト
# 4      な  助詞    終助詞      *      *   *   *      な      ナ      ナ
# <h1>Twitter フォロワー分析</h1>
#             単語  回数
# 0           横国  24
# 1           こと  23
# 2            の  23
# 3           よう  21
# 4            人  21
# 5            春  18
# 6            8  16
# 7        エンジニア  16
# 8            笑  14
# 9         サークル  14
# 10           方  13
# 11          さん  12
# 12  Scaniverse  12
# 13          新歓  12
# 14          相談  12
# 15          自分  11
# 16          参加  11
# 17        サービス  11
# 18     mentory  11
# 19          月額  11
# 20         プラン  11
# 21          柔軟  11
# 22          今日  10
# 23        2022   9
# 24         募集中   8
# 25          大学   8
# 26          大根   8
# 27          特集   7
# 28          東京   7
# 29          出張   7
